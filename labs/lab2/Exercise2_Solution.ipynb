# %% [markdown]
# # Exercise 2 - Problem 1

# %% [markdown]
# ## (a) Import Kaggle Dataset

# %%
# importing our libs 
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
train_data = pd.read_csv("./train.csv")
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ## (b) What are the data types of the vars in the columns?

# %%
print(train_data.dtypes)
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %% [markdown]
# ## (c) Create a new dataframe consisting of only vars if type int

# %%
train_data_numeric = pd.DataFrame(train_data.select_dtypes([np.number]))

# %%
print(train_data_numeric.dtypes)
# Out:
# Id                 int64
# MSSubClass         int64
# LotFrontage      float64
# LotArea            int64
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# MasVnrArea       float64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageYrBlt      float64
# GarageCars         int64
# GarageArea         int64
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# ...

# %% [markdown]
# ## (d) Open the txt and spot the "Actual" numeric values
# Basically age vs phone number kind of thing

# %%
# Just read the damn txt
with open('data_description.txt', 'r') as fin:
    print(fin.read())
# Out:
# MSSubClass: Identifies the type of dwelling involved in the sale.
#
#         20	1-STORY 1946 & NEWER ALL STYLES
#         30	1-STORY 1945 & OLDER
#         40	1-STORY W/FINISHED ATTIC ALL AGES
#         45	1-1/2 STORY - UNFINISHED ALL AGES
#         50	1-1/2 STORY FINISHED ALL AGES
#         60	2-STORY 1946 & NEWER
#         70	2-STORY 1945 & OLDER
#         75	2-1/2 STORY ALL AGES
#         80	SPLIT OR MULTI-LEVEL
#         85	SPLIT FOYER
#         90	DUPLEX - ALL STYLES AND AGES
#        120	1-STORY PUD (Planned Unit Development) - 1946 & NEWER
#        150	1-1/2 STORY PUD - ALL AGES
#        160	2-STORY PUD - 1946 & NEWER
#        180	PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
#        190	2 FAMILY CONVERSION - ALL STYLES AND AGES
#
# MSZoning: Identifies the general zoning classification of the sale.
#
#        A	Agriculture
#        C	Commercial
#        FV	Floating Village Residential
#        I	Industrial
#        RH	Residential High Density
#        RL	Residential Low Density
# ...

# %% [markdown]
# ## (e) drop the non-numerical values from the dataframe

# %%
train_data_numeric.drop(columns = ['MSSubClass', 'OverallQual', 'OverallCond'])
# Out:
#         Id  LotFrontage  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  \
# 0        1         65.0     8450       2003          2003       196.0
# 1        2         80.0     9600       1976          1976         0.0
# 2        3         68.0    11250       2001          2002       162.0
# 3        4         60.0     9550       1915          1970         0.0
# 4        5         84.0    14260       2000          2000       350.0
# ...    ...          ...      ...        ...           ...         ...
# 1455  1456         62.0     7917       1999          2000         0.0
# 1456  1457         85.0    13175       1978          1988       119.0
# 1457  1458         66.0     9042       1941          2006         0.0
# 1458  1459         68.0     9717       1950          1996         0.0
# 1459  1460         75.0     9937       1965          1965         0.0
#
#       BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  ...  WoodDeckSF  \
# ...

# %% [markdown]
# # Exercise 2 - Problem 2

# %% [markdown]
# ## (a) Find the summary statistics of SalePrice from the numeric dataframe from Problem 1
# Summary statistics are: mean, median, quartiles, etc.

# %%
salesprice_stats = train_data_numeric['SalePrice'].describe()
print(salesprice_stats)
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# ## (b) Visualise the summary statistics and distribution of SalePrice
# Using Box-Plot, Histogram, KDE.

# %%
# BoxPlot
f = plt.figure(figsize=(10, 10))
sb.boxplot(data = salesprice_stats, orient = "h")
# Out:
# <AxesSubplot:>

# %%
# Histogram
f = plt.figure(figsize=(10, 10))
sb.histplot(data = salesprice_stats)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Count'>

# %%
# KDE
f = plt.figure(figsize=(10, 10))
sb.kdeplot(data = salesprice_stats)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %% [markdown]
# ## (c) Find the Summary Statistics of LotArea using the numeric dataframe

# %%
lotarea_stats = train_data_numeric['LotArea'].describe()
print(lotarea_stats)
# Out:
# count      1460.000000
# mean      10516.828082
# std        9981.264932
# min        1300.000000
# 25%        7553.500000
# 50%        9478.500000
# 75%       11601.500000
# max      215245.000000
# Name: LotArea, dtype: float64

# %% [markdown]
# ## (d) Visualise the summary statistics and distribution of LotArea using standard Box-Plot, Histogram, KDE

# %%
# Box Plot
f = plt.figure(figsize=(10,10))
sb.boxplot(data = lotarea_stats, orient = "h")
# Out:
# <AxesSubplot:>

# %%
# Histogram
f = plt.figure(figsize=(10, 10))
sb.histplot(data = lotarea_stats)
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='Count'>

# %%
# KDE
f = plt.figure(figsize=(10, 10))
sb.kdeplot(data = lotarea_stats)
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='Density'>

# %% [markdown]
# ## (e) Plot SalePrice vs Lot-Area using jointplot, then find the correlation between the two

# %%
sb.jointplot(data = train_data_numeric, x = "LotArea", y = "SalePrice", height = 10)

# %% [markdown]
# # Bonus Problem

# %% [markdown]
# ## Create a new dataframe - drop the non-numeric variables from the df
# This means dropping the non-actual numeric values too!

# %%
# I'm going to use the previous df bc im lazy
train_data_num = train_data_numeric.copy()
train_data_num.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
# ## Plot SalePrice vs each of the numeric vars - understand their correlation

# %%
# see: https://github.com/ipython/ipython/issues/2172#issuecomment-53708976

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
plt.rcParams.update({'figure.max_open_warning': 0})# see: 
plt.rcParams.update({'figure.max_open_warning': 0})

# %%
columns = list(train_data_num.columns)
columns.remove('SalePrice')
# print(columns)
for col in columns:
    sb.jointplot(data = train_data_num, x = col, y = "SalePrice", height = 10)

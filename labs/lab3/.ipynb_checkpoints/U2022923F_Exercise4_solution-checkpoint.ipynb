# %% [markdown]
# # Exercise 4: Linear Regression

# %% [markdown]
# Made with ❤️ by Dyllon

# %% [markdown]
# ⚠️ Note: Some cells are truncated by Jupyter. To see the full output, select the cell, press ESC, then press Shift+O (I've already done this for some cells, but depending on your machine, you may need to as do it as well)

# %% [markdown]
# Matric Num: U2022923F
# Name: Dyllon Sharad Gunawardhana
# Module: CZ1115
# Lab Group: FSP4

# %%
# import standard libs

import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %% [markdown]
# ## Problem 1: Predicting SalePrice using GrLivArea
# Import the complete dataset “train.csv” in Jupyter : houseData = pd.read_csv('train.csv')
# Use the following Numeric variables from the dataset in this problem : GrLivArea and SalePrice

# %%
# import the data set
houseData = pd.read_csv('./train.csv')
houseData.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ### a) Plot SalePrice against GrLivArea using any appropriate bivariate plot to note the strong linear relationship.

# %%
plot_data = pd.DataFrame(houseData)[['GrLivArea', 'SalePrice']]
plot_data.head()

# draw the plot
sb.jointplot(data = plot_data, x='GrLivArea', y='SalePrice', ratio=10, height=12)
plt.title("SalePrice vs GrLivArea")
plt.xlabel("LotArea")
plt.ylabel("GrLivArea")
plt.show()

# %% [markdown]
# ### b) Print the correlation coefficient between these two variables to get a numerical evidence of the relationship.

# %%
plot_data.corr()
# Out:
#            GrLivArea  SalePrice
# GrLivArea   1.000000   0.708624
# SalePrice   0.708624   1.000000

# %% [markdown]
# ### c) Import Linear Regression model from Scikit-Learn

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### d) Partition the dataset houseData into two “random” portions : Train Data (1100 rows) and Test Data (360 rows).

# %%
train_data = houseData[:1100] # first  1100 rows
test_data = houseData[-360:] # last 360 rows

# %% [markdown]
# ### e) Training : Fit a Linear Regression model on the Train Dataset to predict or estimate SalePrice using GrLivArea.

# %%
grLivArea_train = pd.DataFrame(train_data['GrLivArea'])
salePrice_train = pd.DataFrame(train_data['SalePrice'])

# Create a Linear Regression object
linreg = LinearRegression()

# Train the Linear Regression model
linreg.fit(grLivArea_train, salePrice_train)

print("lin reg model has been trained!")
# Out:
# lin reg model has been trained!

# %% [markdown]
# ### f) Print the coefficients of the Linear Regression model you just fit, and plot the regression line on a scatterplot.

# %%
# Coefficients of the Linear Regression line
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
# Out:
# Intercept 	: b =  [9498.33463562]
# Coefficients 	: a =  [[113.88950443]]

# %%
# Formula for the Regression line
regline_x = grLivArea_train
regline_y = linreg.intercept_ + linreg.coef_ * grLivArea_train

# Plot the Linear Regression line
f = plt.figure(figsize=(16, 8))
plt.scatter(grLivArea_train, salePrice_train)
plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
plt.title("Linear Regression between SalePrice and GrLivArea")
plt.xlabel("GrLivArea")
plt.ylabel("SalePrice")
plt.show()

# %%
# Predict Total values corresponding to HP Train
salePrice_train_pred = linreg.predict(grLivArea_train)

# Coefficients of the Linear Regression line
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)

# Plot the Linear Regression line
f = plt.figure(figsize=(16, 8))
plt.scatter(grLivArea_train, salePrice_train)
plt.scatter(grLivArea_train, salePrice_train_pred, color = "r")
plt.title("Predicting SalePrice with relation to GrLivArea train data")
plt.xlabel("GrLivArea")
plt.ylabel("SalePrice")
plt.show()
# Out:
# Intercept 	: b =  [9498.33463562]
# Coefficients 	: a =  [[113.88950443]]

# %% [markdown]
# ### g) Print Explained Variance (R^2) and Mean Squared Error (MSE) on Train Data to check Goodness of Fit of mode

# %%
from sklearn.metrics import mean_squared_error

# Check the Goodness of Fit (on Train Data)
sp_vs_gla_train_r2 = linreg.score(grLivArea_train, salePrice_train)
sp_vs_gla_train_mse = mean_squared_error(salePrice_train, salePrice_train_pred)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", sp_vs_gla_train_r2)
print("Mean Squared Error (MSE) \t:", sp_vs_gla_train_mse)
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.5317704755454566
# Mean Squared Error (MSE) 	: 2962940662.7214036

# %% [markdown]
# ### h) Predict SalePrice in case of Test Data using the Linear Regression model and the predictor variable GrLivArea.

# %%
# define our test columns
grLivArea_test = pd.DataFrame(train_data['GrLivArea'])
salePrice_test = pd.DataFrame(train_data['SalePrice'])

# %%
# Predict Total values corresponding to HP Test
salePrice_test_pred = linreg.predict(grLivArea_test)

# %% [markdown]
# ### i) Plot the predictions on a Scatterplot of GrLivArea and SalePrice in the Test Data to visualize model accuracy

# %%
# Plot the Predictions
f = plt.figure(figsize=(16, 8))
plt.scatter(grLivArea_test, salePrice_test, color = "green")
plt.scatter(grLivArea_test, salePrice_test_pred, color = "red")
plt.title("Predicting SalePrice with relation to GrLivArea test data")
plt.xlabel("GrLivArea")
plt.ylabel("SalePrice")
plt.show()

# %% [markdown]
# ### j) Print the Mean Squared Error (MSE) on Test Data to check Goodness of Fit of model, compared to the Training

# %%
from sklearn.metrics import mean_squared_error

sp_vs_gla_test_r2 = linreg.score(grLivArea_test, salePrice_test)
sp_vs_gla_test_mse = mean_squared_error(salePrice_test, salePrice_test_pred)

# Comparing our models

f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(salePrice_train, salePrice_train_pred, color = "blue")
axes[0].plot(salePrice_train, salePrice_train, 'r-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(salePrice_test, salePrice_test_pred, color = "green")
axes[1].plot(salePrice_test, salePrice_test, 'r-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", sp_vs_gla_test_r2)
print("Mean Squared Error (MSE) \t:", sp_vs_gla_test_mse)
print()
# Out:
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.5317704755454566
# Mean Squared Error (MSE) 	: 2962940662.7214036

# %% [markdown]
# ## Problem 2
# Perform all the above steps on “SalePrice” against each of the variables “LotArea”, “TotalBsmtSF”, “GarageArea” oneby-one to perform individual Linear Regressions and obtain individual univariate Linear Regression Models in each case.

# %%
selected_x_vars = pd.DataFrame(houseData[['LotArea', 'TotalBsmtSF', 'GarageArea']])
selected_x_vars.describe()
# Out:
#              LotArea  TotalBsmtSF   GarageArea
# count    1460.000000  1460.000000  1460.000000
# mean    10516.828082  1057.429452   472.980137
# std      9981.264932   438.705324   213.804841
# min      1300.000000     0.000000     0.000000
# 25%      7553.500000   795.750000   334.500000
# 50%      9478.500000   991.500000   480.000000
# 75%     11601.500000  1298.250000   576.000000
# max    215245.000000  6110.000000  1418.000000

# %% [markdown]
# ### SalePrice vs LotArea

# %%
# (a)
plot_data = pd.DataFrame(houseData)[['LotArea', 'SalePrice']]
plot_data.head()
sb.jointplot(data = plot_data, x='LotArea', y='SalePrice', ratio=10, height=12)
plt.title("SalePrice vs LotArea")
plt.xlabel("Lot Area")
plt.ylabel("Sale Price")
plt.show()

# (b)
print("Correlation between SalePrice and LotArea")
print(plot_data.corr())
print()

# (c)
# we've already imported the lib previously, there's no need to do it again

# (d)
train_data = houseData[:1100] # first  1100 rows
test_data = houseData[-360:] # last 360 rows

# (e)
LotArea_train = pd.DataFrame(train_data['LotArea'])
salePrice_train = pd.DataFrame(train_data['SalePrice'])
linreg = LinearRegression()
linreg.fit(LotArea_train, salePrice_train)
print("lin reg model has been trained!")

# (f)
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
regline_x = LotArea_train
regline_y = linreg.intercept_ + linreg.coef_ * LotArea_train
f = plt.figure(figsize=(16, 8))
plt.scatter(LotArea_train, salePrice_train)
plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
plt.title("Linear Regression between SalePrice and LotArea")
plt.xlabel("LotArea")
plt.ylabel("SalePrice")
plt.show()

salePrice_train_pred = linreg.predict(LotArea_train)
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
f = plt.figure(figsize=(16, 8))
plt.scatter(LotArea_train, salePrice_train)
plt.scatter(LotArea_train, salePrice_train_pred, color = "r")
plt.title("Predicting SalePrice with relation to LotArea train data")
plt.xlabel("LotArea")
plt.ylabel("SalePrice")
plt.show()

# (g)
from sklearn.metrics import mean_squared_error
sp_vs_la_train_r2 = linreg.score(LotArea_train, salePrice_train)
sp_vs_la_train_mse = mean_squared_error(salePrice_train, salePrice_train_pred)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", sp_vs_la_train_r2)
print("Mean Squared Error (MSE) \t:", sp_vs_la_train_mse)
print()

# (h)
LotArea_test = pd.DataFrame(test_data['LotArea'])
salePrice_test = pd.DataFrame(test_data['SalePrice'])
salePrice_test_pred = linreg.predict(LotArea_test)

# (i)
f = plt.figure(figsize=(16, 8))
plt.scatter(LotArea_test, salePrice_test, color = "green")
plt.scatter(LotArea_test, salePrice_test_pred, color = "red")
plt.title("Predicting SalePrice with relation to LotArea test data")
plt.xlabel("LotArea")
plt.ylabel("SalePrice")
plt.show()

# (j)
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(salePrice_train, salePrice_train_pred, color = "blue")
axes[0].plot(salePrice_train, salePrice_train, 'r-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(salePrice_test, salePrice_test_pred, color = "green")
axes[1].plot(salePrice_test, salePrice_test, 'r-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()
# from sklearn.metrics import mean_squared_error # already imported previously
sp_vs_la_test_r2 = linreg.score(LotArea_test, salePrice_test)
sp_vs_la_test_mse = mean_squared_error(salePrice_test, salePrice_test_pred)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", sp_vs_la_test_r2)
print("Mean Squared Error (MSE) \t:", sp_vs_la_test_mse)
print()
# Out:
# Correlation between SalePrice and LotArea
#             LotArea  SalePrice
# LotArea    1.000000   0.263843
# SalePrice  0.263843   1.000000
#
# lin reg model has been trained!
# Intercept 	: b =  [160963.95370929]
# Coefficients 	: a =  [[1.91881242]]
# Intercept 	: b =  [160963.95370929]
# Coefficients 	: a =  [[1.91881242]]
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.06996047063721678
# Mean Squared Error (MSE) 	: 5885258821.936573
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.06617868448896169
# Mean Squared Error (MSE) 	: 5827711275.733228

# %% [markdown]
# ### SalePrice vs TotalBsmtSF

# %%
# (a)
plot_data = pd.DataFrame(houseData)[['TotalBsmtSF', 'SalePrice']]
plot_data.head()
sb.jointplot(data = plot_data, x='TotalBsmtSF', y='SalePrice', ratio=10, height=12)
plt.title("SalePrice vs TotalBsmtSF")
plt.xlabel("TotalBsmtSF")
plt.ylabel("Sale Price")
plt.show()

# (b)
print("Correlation between SalePrice and TotalBsmtSF")
print(plot_data.corr())
print()

# (c)
# we've already imported the lib previously, there's no need to do it again

# (d)
train_data = houseData[:1100] # first  1100 rows
test_data = houseData[-360:] # last 360 rows

# (e)
TotalBsmtSF_train = pd.DataFrame(train_data['TotalBsmtSF'])
salePrice_train = pd.DataFrame(train_data['SalePrice'])
linreg = LinearRegression()
linreg.fit(TotalBsmtSF_train, salePrice_train)
print("lin reg model has been trained!")

# (f)
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
regline_x = TotalBsmtSF_train
regline_y = linreg.intercept_ + linreg.coef_ * TotalBsmtSF_train
f = plt.figure(figsize=(16, 8))
plt.scatter(TotalBsmtSF_train, salePrice_train)
plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
plt.title("Linear Regression between SalePrice and TotalBsmtSF")
plt.xlabel("TotalBsmtSF")
plt.ylabel("Sale Price")
plt.show()

salePrice_train_pred = linreg.predict(TotalBsmtSF_train)
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
f = plt.figure(figsize=(16, 8))
plt.scatter(TotalBsmtSF_train, salePrice_train)
plt.scatter(TotalBsmtSF_train, salePrice_train_pred, color = "r")
plt.title("Predicting SalePrice with relation to TotalBsmtSF train data")
plt.xlabel("TotalBsmtSF")
plt.ylabel("Sale Price")
plt.show()

# (g)
from sklearn.metrics import mean_squared_error
sp_vs_tbsf_train_r2 = linreg.score(TotalBsmtSF_train, salePrice_train)
sp_vs_tbsf_train_mse = mean_squared_error(salePrice_train, salePrice_train_pred)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", sp_vs_tbsf_train_r2)
print("Mean Squared Error (MSE) \t:", sp_vs_tbsf_train_mse)
print()

# (h)
TotalBsmtSF_test = pd.DataFrame(test_data['TotalBsmtSF'])
salePrice_test = pd.DataFrame(test_data['SalePrice'])
salePrice_test_pred = linreg.predict(TotalBsmtSF_test)

# (i)
f = plt.figure(figsize=(16, 8))
plt.scatter(TotalBsmtSF_test, salePrice_test, color = "green")
plt.scatter(TotalBsmtSF_test, salePrice_test_pred, color = "red")
plt.title("Predicting SalePrice with relation to TotalBsmtSF test data")
plt.xlabel("TotalBsmtSF")
plt.ylabel("Sale Price")
plt.show()

# (j)
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(salePrice_train, salePrice_train_pred, color = "blue")
axes[0].plot(salePrice_train, salePrice_train, 'r-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(salePrice_test, salePrice_test_pred, color = "green")
axes[1].plot(salePrice_test, salePrice_test, 'r-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()
# from sklearn.metrics import mean_squared_error # already imported previously
sp_vs_tbsf_test_r2 = linreg.score(TotalBsmtSF_test, salePrice_test)
sp_vs_tbsf_test_mse = mean_squared_error(salePrice_test, salePrice_test_pred)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", sp_vs_tbsf_test_r2)
print("Mean Squared Error (MSE) \t:", sp_vs_tbsf_test_mse)
print()
# Out:
# Correlation between SalePrice and TotalBsmtSF
#              TotalBsmtSF  SalePrice
# TotalBsmtSF     1.000000   0.613581
# SalePrice       0.613581   1.000000
#
# lin reg model has been trained!
# Intercept 	: b =  [54361.70161283]
# Coefficients 	: a =  [[120.19979559]]
# Intercept 	: b =  [54361.70161283]
# Coefficients 	: a =  [[120.19979559]]
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.4096515413342241
# Mean Squared Error (MSE) 	: 3735705165.951247
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.26305378699344206
# Mean Squared Error (MSE) 	: 4599070168.790179

# %% [markdown]
# ### SalePrice vs GarageArea

# %%
# (a)
plot_data = pd.DataFrame(houseData)[['GarageArea', 'SalePrice']]
plot_data.head()
sb.jointplot(data = plot_data, x='GarageArea', y='SalePrice', ratio=10, height=12)
plt.title("SalePrice vs GarageArea")
plt.xlabel("GarageArea")
plt.ylabel("SalePrice")
plt.show()

# (b)
print("Correlation between SalePrice and GarageArea")
print(plot_data.corr())
print()

# (c)
# we've already imported the lib previously, there's no need to do it again

# (d)
train_data = houseData[:1100] # first  1100 rows
test_data = houseData[-360:] # last 360 rows

# (e)
GarageArea_train = pd.DataFrame(train_data['GarageArea'])
salePrice_train = pd.DataFrame(train_data['SalePrice'])
linreg = LinearRegression()
linreg.fit(GarageArea_train, salePrice_train)
print("lin reg model has been trained!")

# (f)
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
regline_x = GarageArea_train
regline_y = linreg.intercept_ + linreg.coef_ * GarageArea_train
f = plt.figure(figsize=(16, 8))
plt.scatter(GarageArea_train, salePrice_train)
plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
plt.title("Linear Regression between SalePrice and GarageArea")
plt.xlabel("GarageArea")
plt.ylabel("SalePrice")
plt.show()

salePrice_train_pred = linreg.predict(GarageArea_train)
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
f = plt.figure(figsize=(16, 8))
plt.scatter(GarageArea_train, salePrice_train)
plt.scatter(GarageArea_train, salePrice_train_pred, color = "r")
plt.title("Predicting SalePrice with relation to GarageArea train data")
plt.xlabel("GarageArea")
plt.ylabel("SalePrice")
plt.show()

# (g)
from sklearn.metrics import mean_squared_error
sp_vs_ga_train_r2 = linreg.score(GarageArea_train, salePrice_train)
sp_vs_ga_train_mse = mean_squared_error(salePrice_train, salePrice_train_pred)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", sp_vs_ga_train_r2)
print("Mean Squared Error (MSE) \t:", sp_vs_ga_train_mse)
print()

# (h)
GarageArea_test = pd.DataFrame(test_data['GarageArea'])
salePrice_test = pd.DataFrame(test_data['SalePrice'])
salePrice_test_pred = linreg.predict(GarageArea_test)

# (i)
f = plt.figure(figsize=(16, 8))
plt.scatter(GarageArea_test, salePrice_test, color = "green")
plt.scatter(GarageArea_test, salePrice_test_pred, color = "red")
plt.title("Predicting SalePrice with relation to GarageArea test data")
plt.xlabel("GarageArea")
plt.ylabel("SalePrice")
plt.show()

# (j)
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(salePrice_train, salePrice_train_pred, color = "blue")
axes[0].plot(salePrice_train, salePrice_train, 'r-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(salePrice_test, salePrice_test_pred, color = "green")
axes[1].plot(salePrice_test, salePrice_test, 'r-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()
# from sklearn.metrics import mean_squared_error # already imported previously
sp_vs_ga_test_r2 = linreg.score(GarageArea_test, salePrice_test)
sp_vs_ga_test_mse = mean_squared_error(salePrice_test, salePrice_test_pred)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", sp_vs_la_test_r2)
print("Mean Squared Error (MSE) \t:", sp_vs_la_test_mse)
print()
# Out:
# Correlation between SalePrice and GarageArea
#             GarageArea  SalePrice
# GarageArea    1.000000   0.623431
# SalePrice     0.623431   1.000000
#
# lin reg model has been trained!
# Intercept 	: b =  [67131.98072434]
# Coefficients 	: a =  [[241.42776434]]
# Intercept 	: b =  [67131.98072434]
# Coefficients 	: a =  [[241.42776434]]
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.4052658994757937
# Mean Squared Error (MSE) 	: 3763457359.9411798
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.06617868448896169
# Mean Squared Error (MSE) 	: 5827711275.733228

# %% [markdown]
# ## Problem 3
# Compare and contrast the four models in terms of Explained Variance (R^2) and Mean Squared Error (MSE) on Train Data,
# the accuracy of prediction on Test Data, and comment on which model you think is the best to predict “SalePrice”.

# %% [markdown]
# ### SalePrice vs GrLivArea

# %%
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", sp_vs_gla_train_r2)
print("Mean Squared Error (MSE) \t:", sp_vs_gla_train_mse)
print()

print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", sp_vs_gla_test_r2)
print("Mean Squared Error (MSE) \t:", sp_vs_gla_test_mse)
print()
# Out:
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.5317704755454566
# Mean Squared Error (MSE) 	: 2962940662.7214036
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.5317704755454566
# Mean Squared Error (MSE) 	: 2962940662.7214036

# %% [markdown]
# ### SalePrice vs LotArea

# %%
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", sp_vs_la_train_r2)
print("Mean Squared Error (MSE) \t:", sp_vs_la_train_mse)
print()

print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", sp_vs_la_test_r2)
print("Mean Squared Error (MSE) \t:", sp_vs_la_test_mse)
print()
# Out:
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.06996047063721678
# Mean Squared Error (MSE) 	: 5885258821.936573
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.06617868448896169
# Mean Squared Error (MSE) 	: 5827711275.733228

# %% [markdown]
# ### SalePrice vs TotalBsmtSF

# %%
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", sp_vs_tbsf_train_r2)
print("Mean Squared Error (MSE) \t:", sp_vs_tbsf_train_mse)
print()

print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", sp_vs_tbsf_test_r2)
print("Mean Squared Error (MSE) \t:", sp_vs_tbsf_test_mse)
print()
# Out:
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.4096515413342241
# Mean Squared Error (MSE) 	: 3735705165.951247
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.26305378699344206
# Mean Squared Error (MSE) 	: 4599070168.790179

# %% [markdown]
# ### SalePrice vs GarageArea

# %%
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", sp_vs_ga_train_r2)
print("Mean Squared Error (MSE) \t:", sp_vs_ga_train_mse)
print()

print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", sp_vs_ga_test_r2)
print("Mean Squared Error (MSE) \t:", sp_vs_ga_test_mse)
print()
# Out:
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.4052658994757937
# Mean Squared Error (MSE) 	: 3763457359.9411798
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.33415894889143827
# Mean Squared Error (MSE) 	: 4155323226.122655

# %% [markdown]
# ### My Conculsion
# From what we've learnt during the course:
#
# > The **higher** the Explained Variance, the better model
# > The **lower** the Mean Squared Error, the better the model
#
# From the above summaries of R^2 and MSE, we can see that the *SalePrice vs GrLivArea* model has both the highest R^2 and the lowest MSE.
#
# #### ✨ Therefore, *SalePrice vs GrLivArea* is the best model out of the four to predict SalePrice ✨
